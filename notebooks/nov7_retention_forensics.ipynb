# %%
# ------------------------------------------------------------
# Imports + config
# ------------------------------------------------------------
import pandas as pd
import numpy as np
from pathlib import Path
from datetime import datetime


import os, sys, pathlib, importlib

from pathlib import Path
import sys

REPO_ROOT = Path.cwd().parent         
SCRIPTS_DIR = REPO_ROOT / "scripts"
if str(SCRIPTS_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPTS_DIR))

from retention_lib import (
    build_survival_and_hazard,
    merge_brand_intervals,
    derive_entry_plan,
    _normalize_event_columns,
    find_early_annual_churn,
    ALLOWED_PLANS, CAP_DATE
)

DATA_DIR = Path("../data")
RAW_EVENTS = DATA_DIR / "events.csv"              # from 00_ingest
PROC_DIR  = DATA_DIR / "processed"
PROC_DIR.mkdir(parents=True, exist_ok=True)

#CAP = pd.Timestamp("2025-04-29")
CAP = pd.Timestamp("2025-12-31")

# %%
# ------------------------------------------------------------
# Load normalized events (ALL plans) and build survival/hazard with audit
# ------------------------------------------------------------
events = pd.read_csv(RAW_EVENTS, parse_dates=["Start","End"])
surv_0grace, haz_0grace, audit_0grace = build_survival_and_hazard(
    events, 
    allowed_plans=ALLOWED_PLANS, 
    cap_date=CAP,
    max_months=24, 
    grace_days=0, 
    already_events=True,
    apply_exclusions=False, 
    return_audit=True
)

surv_0grace_annual = surv_0grace[surv_0grace['Plan'] == 'premium-plus'].copy()

surv_0grace_annual_2021 = surv_0grace_annual[surv_0grace_annual['Cohort Year'] == 2021].copy()
surv_0grace_annual_2022 = surv_0grace_annual[surv_0grace_annual['Cohort Year'] == 2022].copy()
surv_0grace_annual_2023 = surv_0grace_annual[surv_0grace_annual['Cohort Year'] == 2023].copy()

display(audit_0grace)        # see rows/accounts dropped/changed each stage
display(surv_0grace.head())  # sanity
display(haz_0grace.head())   # sanity
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/nlp_jazzgroove/lib/python3.11/site-packages/pandas/core/arrays/datetimelike.py:559, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     558 try:
# --> 559     self._check_compatible_with(other)
#     560 except (TypeError, IncompatibleFrequency) as err:
#     561     # e.g. tzawareness mismatch
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nlp_jazzgroove/lib/python3.11/site-packages/pandas/core/arrays/datetimes.py:542, in DatetimeArray._check_compatible_with(self, other)
#     541     return
# --> 542 self._assert_tzawareness_compat(other)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nlp_jazzgroove/lib/python3.11/site-packages/pandas/core/arrays/datetimes.py:788, in DatetimeArray._assert_tzawareness_compat(self, other)
#     787 elif other_tz is None:
# --> 788     raise TypeError(
#     789         "Cannot compare tz-naive and tz-aware datetime-like objects"
#     790     )
#
# TypeError: Cannot compare tz-naive and tz-aware datetime-like objects
#
# The above exception was the direct cause of the following exception:
#
# InvalidComparison                         Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/nlp_jazzgroove/lib/python3.11/site-packages/pandas/core/arrays/datetimelike.py:1006, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#    1005 try:
# -> 1006     other = self._validate_comparison_value(other)
#    1007 except InvalidComparison:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nlp_jazzgroove/lib/python3.11/site-packages/pandas/core/arrays/datetimelike.py:562, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     560     except (TypeError, IncompatibleFrequency) as err:
#     561         # e.g. tzawareness mismatch
# --> 562         raise InvalidComparison(other) from err
#     564 elif not is_list_like(other):
#
# InvalidComparison: 2025-12-31 00:00:00
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 # ------------------------------------------------------------
#       2 # Load normalized events (ALL plans) and build survival/hazard with audit
#       3 # ------------------------------------------------------------
#       4 events = pd.read_csv(RAW_EVENTS, parse_dates=["Start","End"])
# ----> 5 surv_0grace, haz_0grace, audit_0grace = build_survival_and_hazard(
#       6     events,
#       7     allowed_plans=ALLOWED_PLANS,
#       8     cap_date=CAP,
#       9     max_months=24,
#      10     grace_days=0,
#      11     already_events=True,
#      12     apply_exclusions=False,
#      13     return_audit=True
#      14 )
#      16 surv_0grace_annual = surv_0grace[surv_0grace['Plan'] == 'premium-plus'].copy()
#      18 surv_0grace_annual_2021 = surv_0grace_annual[surv_0grace_annual['Cohort Year'] == 2021].copy()
#
# File ~/Documents/Contract/paul_jazz_club/churn_and_survival_dashboard/scripts/retention_lib.py:634, in build_survival_and_hazard(df, allowed_plans, cap_date, max_months, grace_days, already_events, apply_exclusions, return_audit)
#     631     if audit is not None:
#     632         audit.add("EXCLUDE: skipped", d, d, note="apply_exclusions=False")
# --> 634 events = _normalize_event_columns(d, cap_date=cap_date, audit=audit, stage_label="NORMALIZE: raw->events" if not already_events else "VERIFY: events (normalize)")
#     635 brand_windows = merge_brand_intervals(events, cap_date=cap_date, grace_days=grace_days, audit=audit, stage_label="MERGE: brand windows")
#     636 entry_plans   = derive_entry_plan(events, allowed_plans=allowed_plans, audit=audit, stage_label="DERIVE: entry plan")
#
# File ~/Documents/Contract/paul_jazz_club/churn_and_survival_dashboard/scripts/retention_lib.py:134, in _normalize_event_columns(df, cap_date, audit, stage_label)
#     132 if cap_date is not None:
#     133     d["End"] = d["End"].fillna(cap_date)
# --> 134     d.loc[d["End"] > cap_date, "End"] = cap_date
#     136 # Keep a clean set of columns
#     137 keep = ["Name_or_Email", "Plan", "Start", "End"]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nlp_jazzgroove/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nlp_jazzgroove/lib/python3.11/site-packages/pandas/core/arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nlp_jazzgroove/lib/python3.11/site-packages/pandas/core/series.py:6130, in Series._cmp_method(self, other, op)
#    6127 lvalues = self._values
#    6128 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6130 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6132 return self._construct_result(res_values, name=res_name)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nlp_jazzgroove/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:330, in comparison_op(left, right, op)
#     321         raise ValueError(
#     322             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     323         )
#     325 if should_extension_dispatch(lvalues, rvalues) or (
#     326     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     327     and lvalues.dtype != object
#     328 ):
#     329     # Call the method on lvalues
# --> 330     res_values = op(lvalues, rvalues)
#     332 elif is_scalar(rvalues) and isna(rvalues):  # TODO: but not pd.NA?
#     333     # numpy does not like comparisons vs None
#     334     if op is operator.ne:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nlp_jazzgroove/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nlp_jazzgroove/lib/python3.11/site-packages/pandas/core/arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nlp_jazzgroove/lib/python3.11/site-packages/pandas/core/arrays/datetimelike.py:1008, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#    1006     other = self._validate_comparison_value(other)
#    1007 except InvalidComparison:
# -> 1008     return invalid_comparison(self, other, op)
#    1010 dtype = getattr(other, "dtype", None)
#    1011 if is_object_dtype(dtype):
#    1012     # We have to use comp_method_OBJECT_ARRAY instead of numpy
#    1013     #  comparison otherwise it would raise when comparing to None
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nlp_jazzgroove/lib/python3.11/site-packages/pandas/core/ops/invalid.py:40, in invalid_comparison(left, right, op)
#      38 else:
#      39     typ = type(right).__name__
# ---> 40     raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      41 return res_values
#
# TypeError: Invalid comparison between dtype=datetime64[ns, UTC] and Timestamp

# %%
events = pd.read_csv(RAW_EVENTS, parse_dates=["Start","End"])
surv, haz, audit = build_survival_and_hazard(
    events, 
    allowed_plans=ALLOWED_PLANS, 
    cap_date=CAP,
    max_months=24, 
    grace_days=90, 
    already_events=True,
    apply_exclusions=False, 
    return_audit=True
)

display(audit)        # see rows/accounts dropped/changed each stage
display(surv.head())  # sanity
display(haz.head())   # sanity
# Out:
#                     stage  rows_before  rows_after  delta_rows  \
# 0        EXCLUDE: skipped        19785       19785           0
# 1  NORMALIZE: raw->events        19785       19738         -47
# 2    MERGE: brand windows        19785       12969       -6816
#
#    accounts_before  accounts_after  delta_accounts  \
# 0            11237           11237               0
# 1            11237           11214             -23
# 2            11237           11214             -23
#
#                                                 note
# 0                   No exclusion columns or disabled
# 1  Normalize Start/End; cap future End; drop rows...
# 2                     members=11214 -> windows=12969
#            Plan  Cohort Year  Month  At_Risk  Retention
# 0  premium-plus         2019      1     2161   1.000000
# 1  premium-plus         2019      2     2161   1.000000
# 2  premium-plus         2019      3     2155   0.997224
# 3  premium-plus         2019      4     2126   0.983804
# 4  premium-plus         2019      5     2123   0.982416
#            Plan  Month  At_Risk  Exits  Avg_Hazard
# 0  premium-plus      1     9526      0    0.000000
# 1  premium-plus      2     9471     55    0.005807
# 2  premium-plus      3     8783    688    0.078333
# 3  premium-plus      4     8419    364    0.043236
# 4  premium-plus      5     8331     88    0.010563

# %%
surv_annual = surv[surv['Plan'] == 'premium-plus'].copy()

surv_annual_2021 = surv_annual[surv_annual['Cohort Year'] == 2021].copy()
surv_annual_2022 = surv_annual[surv_annual['Cohort Year'] == 2022].copy()
surv_annual_2023 = surv_annual[surv_annual['Cohort Year'] == 2023].copy()

surv_annual_2021.head(10)
# Out:
#             Plan  Cohort Year  Month  At_Risk  Retention
# 48  premium-plus         2021      1     1666   1.000000
# 49  premium-plus         2021      2     1655   0.993397
# 50  premium-plus         2021      3     1608   0.965186
# 51  premium-plus         2021      4     1508   0.905162
# 52  premium-plus         2021      5     1488   0.893157
# 53  premium-plus         2021      6     1412   0.847539
# 54  premium-plus         2021      7     1350   0.810324
# 55  premium-plus         2021      8     1330   0.798319
# 56  premium-plus         2021      9     1323   0.794118
# 57  premium-plus         2021     10     1304   0.782713

# %%
surv_0grace_annual_2021.head(10)
# Out:
#             Plan  Cohort Year  Month  At_Risk  Retention
# 48  premium-plus         2021      1     1933   1.000000
# 49  premium-plus         2021      2     1912   0.989136
# 50  premium-plus         2021      3     1862   0.963270
# 51  premium-plus         2021      4     1756   0.908432
# 52  premium-plus         2021      5     1734   0.897051
# 53  premium-plus         2021      6     1647   0.852043
# 54  premium-plus         2021      7     1579   0.816865
# 55  premium-plus         2021      8     1556   0.804966
# 56  premium-plus         2021      9     1549   0.801345
# 57  premium-plus         2021     10     1527   0.789964

# %%
surv_annual_2022.head(10)
# Out:
#             Plan  Cohort Year  Month  At_Risk  Retention
# 72  premium-plus         2022      1      911   1.000000
# 73  premium-plus         2022      2      901   0.989023
# 74  premium-plus         2022      3      891   0.978046
# 75  premium-plus         2022      4      878   0.963776
# 76  premium-plus         2022      5      874   0.959385
# 77  premium-plus         2022      6      865   0.949506
# 78  premium-plus         2022      7      858   0.941822
# 79  premium-plus         2022      8      856   0.939627
# 80  premium-plus         2022      9      853   0.936334
# 81  premium-plus         2022     10      852   0.935236

# %%
surv_annual_2023.head(10)
# Out:
#              Plan  Cohort Year  Month  At_Risk  Retention
# 96   premium-plus         2023      1     1169   1.000000
# 97   premium-plus         2023      2     1158   0.990590
# 98   premium-plus         2023      3     1080   0.923867
# 99   premium-plus         2023      4     1034   0.884517
# 100  premium-plus         2023      5     1016   0.869119
# 101  premium-plus         2023      6     1008   0.862275
# 102  premium-plus         2023      7      985   0.842601
# 103  premium-plus         2023      8      920   0.786997
# 104  premium-plus         2023      9      900   0.769889
# 105  premium-plus         2023     10      896   0.766467

# %%
# ------------------------------------------------------------
# Forensics: early annual 'churn' under brand-aware logic
# ------------------------------------------------------------
events_norm   = _normalize_event_columns(events, cap_date=CAP)
brand_windows = merge_brand_intervals(events_norm, cap_date=CAP, grace_days=0)
entry_plans   = derive_entry_plan(events_norm, allowed_plans=ALLOWED_PLANS)

early_pp = find_early_annual_churn(events_norm, brand_windows, entry_plans, months=12)

early_pp.columns
# Out:
# Index(['Name_or_Email', 'BrandStart', 'BrandEnd', 'Entry_Plan', 'First_Start',
#        'LastMonth', 'censored', 'had_other_plan_overlap', 'other_plans'],
#       dtype='object')

# %%
early_pp
# Out:
#                    Name_or_Email          BrandStart            BrandEnd  \
# 2975        support@audiopump.co 2019-06-19 19:32:46 2019-12-09 16:01:44
# 2321   paul+352P20June@gmail.com 2019-06-20 15:53:06 2019-12-09 16:01:44
# 1598        juan.uno@verizon.net 2019-06-22 10:05:18 2020-01-18 08:10:04
# 1642   katrinquosdorf@icloud.com 2019-06-23 01:35:51 2019-12-09 16:01:46
# 1165          gpietro7@gmail.com 2019-06-23 04:24:06 2019-12-22 20:24:05
# ...                          ...                 ...                 ...
# 14012                        NaN                 NaT                 NaT
# 14016                        NaN                 NaT                 NaT
# 14028                        NaN                 NaT                 NaT
# 14032                        NaN                 NaT                 NaT
# 14039                        NaN                 NaT                 NaT
#
#          Entry_Plan         First_Start  LastMonth censored  \
# 2975   premium-plus 2019-06-19 19:32:46          7    False
# 2321   premium-plus 2019-06-20 15:53:06          7    False
# 1598   premium-plus 2019-06-22 10:05:18          8    False
# 1642   premium-plus 2019-06-23 01:35:51          7    False
# 1165   premium-plus 2019-06-23 04:24:06          7    False
# ...             ...                 ...        ...      ...
# 14012           NaN                 NaT       <NA>      NaN
# 14016           NaN                 NaT       <NA>      NaN
# 14028           NaN                 NaT       <NA>      NaN
# 14032           NaN                 NaT       <NA>      NaN
# 14039           NaN                 NaT       <NA>      NaN
#
#       had_other_plan_overlap other_plans
# 2975                     NaN         NaN
# 2321                     NaN         NaN
# 1598                     NaN         NaN
# 1642                   False
# 1165                     NaN         NaN
# ...                      ...         ...
# 14012                  False
# 14016                  False
# 14028                  False
# 14032                  False
# 14039                  False
#
# [5881 rows x 9 columns]

# %%
print("Total early annual (<12m):", len(early_pp))
#display(early_pp.head(50))

# Split by cohort year for 2022 vs 2023
early_2021 = early_pp[early_pp["First_Start"].dt.year == 2021]
early_2022 = early_pp[early_pp["First_Start"].dt.year == 2022]
early_2023 = early_pp[early_pp["First_Start"].dt.year == 2023]
print("Early PP 2022:", len(early_2022), " | Early PP 2023:", len(early_2023))

# Save for manual QA with billing logs
#early_pp.to_csv(PROC_DIR / "early_annual_cancels_all.csv", index=False)
#early_2022.to_csv(PROC_DIR / "early_annual_cancels_2022.csv", index=False)
#early_2023.to_csv(PROC_DIR / "early_annual_cancels_2023.csv", index=False)
# Out:
# Total early annual (<12m): 5881
# Early PP 2022: 171  | Early PP 2023: 463

# %%
early_2021
# Out:
#                   Name_or_Email          BrandStart            BrandEnd  \
# 3334  zimakov.zimakov@gmail.com 2021-01-01 02:17:38 2021-06-01 02:17:40
# 1738           lab90210@msn.com 2021-01-01 02:46:46 2021-04-01 02:46:49
# 1225     hardrain77@hotmail.com 2021-01-01 06:48:57 2021-02-01 06:49:01
# 525     christian.werle@gmx.com 2021-01-01 09:40:35 2021-03-01 09:40:36
# 945        ericquebec@gmail.com 2021-01-01 14:03:08 2021-05-01 14:03:15
# ...                         ...                 ...                 ...
# 2676      rodandhenry@yahoo.com 2021-12-28 16:35:01 2022-02-28 16:35:53
# 1403          jawinslow@msn.com 2020-11-15 08:17:01 2021-11-15 08:17:06
# 2762  sallymorton@bellsouth.net 2021-12-29 14:04:44 2022-07-29 14:04:46
# 2585         rdfreson@yahoo.com 2021-12-31 00:00:00 2022-05-31 00:00:28
# 670       danhandke@hotmail.com 2021-12-31 00:00:00 2022-10-31 00:00:16
#
#         Entry_Plan         First_Start  LastMonth censored  \
# 3334  premium-plus 2021-01-01 02:17:38          6    False
# 1738  premium-plus 2021-01-01 02:46:46          4    False
# 1225  premium-plus 2021-01-01 06:48:57          2    False
# 525   premium-plus 2021-01-01 09:40:35          3    False
# 945   premium-plus 2021-01-01 14:03:08          5    False
# ...            ...                 ...        ...      ...
# 2676  premium-plus 2021-12-28 16:35:01          3    False
# 1403  premium-plus 2021-12-28 17:04:58          0    False
# 2762  premium-plus 2021-12-29 14:04:44          8    False
# 2585  premium-plus 2021-12-31 00:00:00          6    False
# 670   premium-plus 2021-12-31 00:00:00         11    False
#
#      had_other_plan_overlap other_plans
# 3334                    NaN         NaN
# 1738                    NaN         NaN
# 1225                    NaN         NaN
# 525                     NaN         NaN
# 945                     NaN         NaN
# ...                     ...         ...
# 2676                    NaN         NaN
# 1403                  False
# 2762                    NaN         NaN
# 2585                  False
# 670                     NaN         NaN
#
# [512 rows x 9 columns]
